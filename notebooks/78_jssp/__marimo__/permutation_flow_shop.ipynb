# %%
import marimo as mo

# %%
import random
import pyscipopt as scip

# %% [markdown]
# # 順列フローショップ問題

# %% [markdown]
# $n$ 個のジョブを $m$ 台のマシンで順番に処理する.
# 各ジョブはマシン 1, マシン 2, ... で順に処理されマシン $m$ で処理されると完了になる.
#
# ![](https://www.researchgate.net/profile/Mariusz-Makuchowski/publication/280775329/figure/fig1/AS:284468087672848@1444833885900/Schedules-of-the-different-variants-of-the-flow-shop-problem.png)

# %% [markdown]
# ## 位置データ定式化

# %% [markdown]
# ## 定数
#
# - ジョブ: $J = \{ 1, \dots, n \}$
# - マシン: $M = \{ 1, \dots, m \}$
# - 処理時間: $p_{ij} \ (\forall i \in M, \forall j \in J)$
#
# ## 決定変数
#
# - $x_{j \kappa} \in \{ 0, 1 \}$: ジョブ $j$ を並べた時の順番が $\kappa$ 番目であるとき $1$.
# - $s_{i \kappa}$: マシン $i$ の $\kappa$ 番目に並べられているジョブの開始時刻
# - $f_{i \kappa}$: マシン $i$ の $\kappa$ 番目に並べられているジョブの終了時刻

# %% [markdown]
# \begin{align*}
# &\text{minimize} &f_{mn} \\
# &\text{s.t.} &\sum_{\kappa} x_{j \kappa} &= 1 \ &(\forall j \in J) \\
# & &\sum_{j \in J} x_{j \kappa} &= 1 \ &(\forall \kappa = 1, \dots, n) \\
# & &f_{i \kappa} &\leq s_{i,\kappa+1} \ &(\forall i \in M, \forall \kappa = 1, \dots, n-1) \\
# & &s_{i \kappa} + \sum_{j \in J} p_{ij} x_{j \kappa} &\leq f_{i \kappa} \ &(\forall i \in M, \forall \kappa = 1, \dots, n) \\
# & &f_{i \kappa} &\leq s_{i+1, \kappa} \ &(\forall i \in M \setminus \{m\}, \forall \kappa = 1, \dots, n) \\
# & &x_{j \kappa} &\in \{ 0, 1 \} \ &(\forall j \in J, \kappa = 1, \dots, n) \\
# & &s_{i \kappa} &\geq 0 \ &(\forall i \in M, \kappa = 1, \dots, n) \\
# & &f_{i \kappa} &\geq 0 \ &(\forall i \in M, \kappa = 1, \dots, n) \\
# \end{align*}

# %% [markdown]
# ## 実装

# %%
def make_data_permutation_flow_shop(n, m):
    """make_data: prepare matrix of m times n random processing times"""
    random.seed(0)
    p = {}
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            p[i, j] = random.randint(1, 10)
    return p

# %%
def permutation_flow_shop(n, m, p):
    """permutation_flow_shop problem
    Parameters:
        - n: number of jobs
        - m: number of machines
        - p[i,j]: processing time of job i on machine j
    Returns a model, ready to be solved.
    """
    model = scip.Model("permutation flow shop")
    x, s, f = {}, {}, {}
    for j in range(1, n + 1):
        for k in range(1, n + 1):
            x[j, k] = model.addVar(vtype="B", name="x(%s,%s)" % (j, k))

    for i in range(1, m + 1):
        for k in range(1, n + 1):
            s[i, k] = model.addVar(vtype="C", name="start(%s,%s)" % (i, k))
            f[i, k] = model.addVar(vtype="C", name="finish(%s,%s)" % (i, k))

    for j in range(1, n + 1):
        model.addCons(
            scip.quicksum(x[j, k] for k in range(1, n + 1)) == 1,
            "Assign1(%s)" % (j),
        )
        model.addCons(
            scip.quicksum(x[k, j] for k in range(1, n + 1)) == 1,
            "Assign2(%s)" % (j),
        )

    for i in range(1, m + 1):
        for k in range(1, n + 1):
            if k != n:
                model.addCons(
                    f[i, k] <= s[i, k + 1], "FinishStart(%s,%s)" % (i, k)
                )
            if i != m:
                model.addCons(
                    f[i, k] <= s[i + 1, k], "Machine(%s,%s)" % (i, k)
                )

            model.addCons(
                s[i, k]
                + scip.quicksum(p[i, j] * x[j, k] for j in range(1, n + 1))
                <= f[i, k],
                "StartFinish(%s,%s)" % (i, k),
            )

    model.setObjective(f[m, n], sense="minimize")

    return model, x, s, f

# %%
n = 10
m = 10
p = make_data_permutation_flow_shop(n, m)

model, x, s, f = permutation_flow_shop(n, m, p)
model.optimize()
print("Opt.value=", model.getObjVal())
# Out:
# presolving:
# (round 1, fast)       1 del vars, 0 del conss, 0 add conss, 1 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 2, fast)       3 del vars, 2 del conss, 0 add conss, 1 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# Opt.value= 121.00000000000003
# (round 3, exhaustive) 5 del vars, 4 del conss, 0 add conss, 3 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 4, fast)       5 del vars, 4 del conss, 0 add conss, 6 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 5, fast)       7 del vars, 6 del conss, 0 add conss, 6 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 6, fast)       7 del vars, 6 del conss, 0 add conss, 9 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 7, fast)       9 del vars, 8 del conss, 0 add conss, 9 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 8, fast)       9 del vars, 8 del conss, 0 add conss, 13 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 9, fast)       11 del vars, 10 del conss, 0 add conss, 13 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 10, fast)       11 del vars, 10 del conss, 0 add conss, 17 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 11, fast)       13 del vars, 12 del conss, 0 add conss, 17 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 12, fast)       13 del vars, 12 del conss, 0 add conss, 22 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 13, fast)       15 del vars, 14 del conss, 0 add conss, 22 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 14, fast)       15 del vars, 14 del conss, 0 add conss, 27 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 15, fast)       17 del vars, 16 del conss, 0 add conss, 27 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 16, fast)       17 del vars, 16 del conss, 0 add conss, 33 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 17, fast)       21 del vars, 20 del conss, 0 add conss, 33 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 18, fast)       21 del vars, 20 del conss, 0 add conss, 37 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 19, fast)       21 del vars, 20 del conss, 0 add conss, 42 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 20, fast)       21 del vars, 20 del conss, 0 add conss, 47 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 21, fast)       21 del vars, 20 del conss, 0 add conss, 53 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 22, fast)       21 del vars, 20 del conss, 0 add conss, 59 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 23, fast)       21 del vars, 20 del conss, 0 add conss, 66 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 24, fast)       21 del vars, 20 del conss, 0 add conss, 73 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 25, fast)       21 del vars, 20 del conss, 0 add conss, 81 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 26, fast)       21 del vars, 20 del conss, 0 add conss, 89 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 27, fast)       21 del vars, 20 del conss, 0 add conss, 98 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 28, fast)       23 del vars, 22 del conss, 0 add conss, 98 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 29, fast)       23 del vars, 22 del conss, 0 add conss, 105 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 30, fast)       23 del vars, 22 del conss, 0 add conss, 113 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 31, fast)       25 del vars, 24 del conss, 0 add conss, 113 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 32, fast)       25 del vars, 24 del conss, 0 add conss, 119 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 33, fast)       25 del vars, 24 del conss, 0 add conss, 126 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 34, fast)       27 del vars, 26 del conss, 0 add conss, 126 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 35, fast)       27 del vars, 26 del conss, 0 add conss, 131 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 36, fast)       27 del vars, 26 del conss, 0 add conss, 137 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 37, fast)       29 del vars, 28 del conss, 0 add conss, 137 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 38, fast)       29 del vars, 28 del conss, 0 add conss, 141 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 39, fast)       29 del vars, 28 del conss, 0 add conss, 146 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 40, fast)       31 del vars, 30 del conss, 0 add conss, 146 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 41, fast)       31 del vars, 30 del conss, 0 add conss, 149 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 42, fast)       31 del vars, 30 del conss, 0 add conss, 153 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 43, fast)       33 del vars, 32 del conss, 0 add conss, 153 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 44, exhaustive) 33 del vars, 32 del conss, 0 add conss, 158 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 45, fast)       35 del vars, 34 del conss, 0 add conss, 158 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 46, exhaustive) 35 del vars, 34 del conss, 0 add conss, 161 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 47, fast)       37 del vars, 36 del conss, 0 add conss, 161 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 48, exhaustive) 38 del vars, 37 del conss, 0 add conss, 162 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 49, exhaustive) 38 del vars, 37 del conss, 0 add conss, 162 chg bounds, 0 chg sides, 0 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
#    (0.0s) sparsify finished: 257/1675 (15.3%) nonzeros canceled - in total 257 canceled nonzeros, 990 changed coefficients, 0 added nonzeros
# (round 50, exhaustive) 38 del vars, 37 del conss, 0 add conss, 162 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 51, fast)       38 del vars, 37 del conss, 0 add conss, 209 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 52, fast)       38 del vars, 37 del conss, 0 add conss, 261 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 53, fast)       38 del vars, 37 del conss, 0 add conss, 317 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 54, fast)       38 del vars, 37 del conss, 0 add conss, 366 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 55, fast)       38 del vars, 37 del conss, 0 add conss, 398 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 56, fast)       38 del vars, 37 del conss, 0 add conss, 425 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 57, fast)       38 del vars, 37 del conss, 0 add conss, 441 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 58, fast)       38 del vars, 37 del conss, 0 add conss, 450 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 59, fast)       38 del vars, 37 del conss, 0 add conss, 456 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 60, fast)       38 del vars, 37 del conss, 0 add conss, 462 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 61, exhaustive) 38 del vars, 37 del conss, 0 add conss, 527 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 62, fast)       38 del vars, 37 del conss, 0 add conss, 575 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 63, fast)       38 del vars, 37 del conss, 0 add conss, 619 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 64, fast)       38 del vars, 37 del conss, 0 add conss, 660 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 65, fast)       38 del vars, 37 del conss, 0 add conss, 698 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 66, fast)       38 del vars, 37 del conss, 0 add conss, 739 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 67, fast)       38 del vars, 37 del conss, 0 add conss, 777 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 68, fast)       38 del vars, 37 del conss, 0 add conss, 817 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 69, fast)       38 del vars, 37 del conss, 0 add conss, 853 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 70, fast)       38 del vars, 37 del conss, 0 add conss, 891 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 71, fast)       38 del vars, 37 del conss, 0 add conss, 930 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 72, fast)       38 del vars, 37 del conss, 0 add conss, 973 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 73, fast)       38 del vars, 37 del conss, 0 add conss, 1014 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 74, fast)       38 del vars, 37 del conss, 0 add conss, 1057 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 75, fast)       38 del vars, 37 del conss, 0 add conss, 1098 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 76, fast)       38 del vars, 37 del conss, 0 add conss, 1140 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 77, fast)       38 del vars, 37 del conss, 0 add conss, 1177 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 78, fast)       38 del vars, 37 del conss, 0 add conss, 1212 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 79, fast)       38 del vars, 37 del conss, 0 add conss, 1244 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 80, fast)       38 del vars, 37 del conss, 0 add conss, 1268 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 81, fast)       38 del vars, 37 del conss, 0 add conss, 1291 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 82, fast)       38 del vars, 37 del conss, 0 add conss, 1311 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 83, fast)       38 del vars, 37 del conss, 0 add conss, 1326 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 84, fast)       38 del vars, 37 del conss, 0 add conss, 1339 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 85, fast)       38 del vars, 37 del conss, 0 add conss, 1350 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 86, fast)       38 del vars, 37 del conss, 0 add conss, 1360 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 87, fast)       38 del vars, 37 del conss, 0 add conss, 1368 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 88, fast)       38 del vars, 37 del conss, 0 add conss, 1376 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 89, fast)       38 del vars, 37 del conss, 0 add conss, 1379 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 90, fast)       38 del vars, 37 del conss, 0 add conss, 1384 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
# (round 91, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1388 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 0 impls, 20 clqs, 0 implints
#    (0.0s) probing cycle finished: starting next cycle
# (round 92, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1529 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 8186 impls, 20 clqs, 0 implints
#    (0.0s) probing cycle finished: starting next cycle
# (round 93, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1592 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 8363 impls, 20 clqs, 0 implints
#    (0.0s) probing cycle finished: starting next cycle
# (round 94, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1630 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 8436 impls, 20 clqs, 0 implints
#    (0.1s) probing cycle finished: starting next cycle
# (round 95, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1654 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 8471 impls, 20 clqs, 0 implints
#    (0.1s) probing cycle finished: starting next cycle
# (round 96, exhaustive) 38 del vars, 37 del conss, 0 add conss, 1666 chg bounds, 0 chg sides, 990 chg coeffs, 20 upgd conss, 8477 impls, 20 clqs, 0 implints
#    (0.1s) probing: 81/100 (81.0%) - 0 fixings, 0 aggregations, 12864 implications, 277 bound changes
#    (0.1s) probing aborted: 50/50 successive totally useless probings
#    (0.1s) symmetry computation started: requiring (bin +, int +, cont +), (fixed: bin -, int -, cont -)
#    (0.1s) no symmetry present (symcode time: 0.00)
# presolving (97 rounds: 97 fast, 14 medium, 14 exhaustive):
#  38 deleted vars, 37 deleted constraints, 0 added constraints, 1666 tightened bounds, 0 added holes, 0 changed sides, 990 changed coefficients
#  8477 implications, 20 cliques, 0 implied integral variables (0 bin, 0 int, 0 cont)
# presolved problem has 262 variables (100 bin, 0 int, 162 cont) and 263 constraints
#      20 constraints of type <setppc>
#     243 constraints of type <linear>
# Presolving Time: 0.07
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p 0.1s|     1 |     0 |    91 |     - |  clique|   0 | 262 | 263 | 263 |   0 |  0 |   0 |   0 | 2.000000e+01 | 1.530000e+02 | 665.00%| unknown
# p 0.1s|     1 |     0 |   212 |     - |   locks|   0 | 262 | 263 | 263 |   0 |  0 |   0 |   0 | 2.000000e+01 | 1.410000e+02 | 605.00%| unknown
#   0.1s|     1 |     0 |  1607 |     - |  5210k |   0 | 262 | 263 | 263 |   0 |  0 |   0 |   0 | 1.101003e+02 | 1.410000e+02 |  28.07%| unknown
#   0.1s|     1 |     0 |  1607 |     - |  5306k |   0 | 262 | 263 | 263 |   0 |  0 |   0 |   0 | 1.101003e+02 | 1.410000e+02 |  28.07%| unknown
#   0.1s|     1 |     0 |  1775 |     - |  6141k |   0 | 262 | 263 | 268 |   5 |  1 |   0 |   0 | 1.117037e+02 | 1.410000e+02 |  26.23%| unknown
#   0.2s|     1 |     0 |  1865 |     - |  7850k |   0 | 262 | 264 | 270 |   7 |  2 |   1 |   0 | 1.119957e+02 | 1.410000e+02 |  25.90%| unknown
#   0.2s|     1 |     0 |  1893 |     - |  9096k |   0 | 262 | 264 | 273 |  10 |  3 |   1 |   0 | 1.120227e+02 | 1.410000e+02 |  25.87%| unknown
#   0.3s|     1 |     0 |  1936 |     - |  9662k |   0 | 262 | 264 | 275 |  12 |  4 |   1 |   0 | 1.120440e+02 | 1.410000e+02 |  25.84%| unknown
